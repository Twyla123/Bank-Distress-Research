# %%
import os
import zipfile
import pyreadstat
import pandas as pd

# %% [markdown]
# # Get a list of variable names (from https://rpubs.com/simaan84/bhc)

# %%
# I used the variable name list provided by Majeed Simaan, since I could not find the list.  
data = {
    'Description': ["id", "date", "parent_id", "country", "name", "name_legal", 
                    "fed_district_code", "org_type", "charter_type", "fed_regulator2", 
                    "fed_regulator", "lei", "lei", "city", "state"],
    'Code': ["RSSD9001", "RSSD9999", "RSSD9364", "RSSD9005", "RSSD9010", "RSSD9017", 
             "RSSD9032", "RSSD9047", "RSSD9048", "RSSD9217", "PRIM_FED_REG", "ID.LEI", 
             "ID_LEI", "RSSD9130", "RSSD9200"]
}

# Convert dictionary to DataFrame
var_df = pd.DataFrame(data)

# %%
var_df
# Out:
#           Description          Code
# 0                  id      RSSD9001
# 1                date      RSSD9999
# 2           parent_id      RSSD9364
# 3             country      RSSD9005
# 4                name      RSSD9010
# 5          name_legal      RSSD9017
# 6   fed_district_code      RSSD9032
# 7            org_type      RSSD9047
# 8        charter_type      RSSD9048
# 9      fed_regulator2      RSSD9217
# 10      fed_regulator  PRIM_FED_REG
# 11                lei        ID.LEI
# 12                lei        ID_LEI
# 13               city      RSSD9130
# 14              state      RSSD9200

# %% [markdown]
# # import Call Reports

# %%
# Set the data directory path 
data_dir = '/Users/twylazhang/Desktop/Econ_DS_Research/background/COM'


# Get a list of names of zip files, since there are four zip files. 
zip_files = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith('.zip')]

# Unzip the files
for zip_file in zip_files:
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(data_dir)

# List of names of all .xpt files after unzipping
xpt_files = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith('.xpt')]


# Select the variables of interest
variables_of_interest = var_df['Code'].tolist()  

# Since each file have many other columns of data, 
# we only want variables of interest. So we read the .xpt files and filter by variables of interest. 
filtered_data_list = []
for file_path in xpt_files:
    df, meta = pyreadstat.read_xport(file_path, usecols=variables_of_interest)
    filtered_data_list.append(df)

# Combine data from all four files into a single data frame
call = pd.concat(filtered_data_list, ignore_index=True)

# Rename the columns using var_df by mapping 'Code' to 'Description'
var_name_to_label = pd.Series(var_df['Description'].values, index=var_df['Code']).to_dict()
call.rename(columns=var_name_to_label, inplace=True)

# Replace parent_id values that are zero with the corresponding id values
call.loc[call['parent_id'] == 0, 'parent_id'] = call.loc[call['parent_id'] == 0, 'id']

# Drop all rows with any missing values
call.dropna(inplace=True)

# Display the updated DataFrame
call
# Out:
#              date         id  charter_type                        name_legal  \
# 0      20170930.0       37.0         200.0            BANK OF HANCOCK COUNTY
# 1      20170930.0      242.0         200.0  FIRST COMMUNITY BANK XENIA-FLORA
# 2      20170930.0      279.0         300.0       MINEOLA COMMUNITY BANK, SSB
# 3      20170930.0      354.0         200.0                  BISON STATE BANK
# 4      20170930.0      457.0         200.0                  LOWRY STATE BANK
# ...           ...        ...           ...                               ...
# 24204  20170331.0  5050028.0         200.0    INTERNATIONAL BANK OF COMMERCE
# 24205  20170331.0  5083316.0           0.0         DESJARDINS FLORIDA BRANCH
# 24206  20170331.0  5086072.0         200.0                    BLUE GATE BANK
# 24207  20170331.0  5087752.0           0.0                     HUDSON BRANCH
# 24208  20170331.0  5113866.0           0.0                   NEW YORK BRANCH
#
#                                name  org_type  fed_district_code  \
# 0               BANK OF HANCOCK CTY       1.0                6.0
# 1        FIRST CMNTY BK XENIA FLORA       1.0                8.0
# 2              MINEOLA CMNTY BK SSB       6.0               11.0
# 3                       BISON ST BK       1.0               10.0
# 4                       LOWRY ST BK       1.0                9.0
# ...                             ...       ...                ...
# 24204      INTERNATIONAL BK OF CMRC       1.0               10.0
# 24205  FEDERATION DES CAISSES FL BR       0.0                0.0
# 24206                  BLUE GATE BK       1.0               12.0
# 24207  ROYAL BK OF CANADA HUDSON BR       0.0                0.0
# 24208           TAIWAN BUS BK NY BR       0.0                0.0
#
#                 city        country state fed_regulator2 lei  parent_id
# 0             SPARTA  UNITED STATES    GA           FDIC   0       37.0
# 1              XENIA  UNITED STATES    IL            FRS   0  3088643.0
# 2            MINEOLA  UNITED STATES    TX           FDIC   0  3619720.0
# 3              BISON  UNITED STATES    KS           FDIC   0      354.0
# 4              LOWRY  UNITED STATES    MN           FDIC   0  1127016.0
# ...              ...            ...   ...            ...  ..        ...
# 24204  OKLAHOMA CITY  UNITED STATES    OK           FDIC   0  1104231.0
# 24205     HALLANDALE  UNITED STATES    FL            OCC   0  5083316.0
# 24206     COSTA MESA  UNITED STATES    CA           FDIC   0  5086072.0
# 24207    JERSEY CITY  UNITED STATES    NJ            OCC   0  5087752.0
# 24208       NEW YORK  UNITED STATES    NY            FRS   0  5113866.0
#
# [24207 rows x 13 columns]

# %%
call.describe()
# Out:
#                date            id  charter_type      org_type  \
# count  2.420700e+04  2.420700e+04  24207.000000  24207.000000
# mean   2.017078e+07  1.010802e+06    208.452514      1.301731
# std    3.354635e+02  1.058036e+06     54.537115      1.287387
# min    2.017033e+07  3.700000e+01      0.000000      0.000000
# 25%    2.017033e+07  3.282075e+05    200.000000      1.000000
# 50%    2.017063e+07  6.531340e+05    200.000000      1.000000
# 75%    2.017093e+07  9.667310e+05    200.000000      1.000000
# max    2.017123e+07  5.143788e+06    400.000000     11.000000
#
#        fed_district_code     parent_id
# count       24207.000000  2.420700e+04
# mean            7.157847  1.970430e+06
# std             3.198892  1.252251e+06
# min             0.000000  3.700000e+01
# 25%             6.000000  1.084696e+06
# 50%             7.000000  1.249105e+06
# 75%            10.000000  3.005332e+06
# max            12.000000  5.170805e+06

# %% [markdown]
# # FR Y-9C Reports

# %%
# Set the directory paths
data_dir = '/Users/twylazhang/Desktop/Econ_DS_Research/background/HOLD'


# List all CSV files in the directory (assumes you want all CSV files in the directory)
csv_files = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith('.csv')]


# Read and combine all CSV files into one DataFrame
combined_FR = pd.concat([pd.read_csv(file, low_memory=False) for file in csv_files], ignore_index=True)

# %% [markdown]
# Since there were over 2000 columns in combined_FR, only keep those that are important

# %%
len(combined_FR.columns)
# Out:
# 2486

# %%
# Rename the columns using the dictionary
combined_FR.rename(columns=var_name_to_label, inplace=True)

# Filter the DataFrame to keep only renamed columns
# Create a set of new column names from the dictionary for filtering
new_column_names = set(var_name_to_label.values())

# Keep only the columns that are in new_column_names
combined_FR = combined_FR.loc[:, combined_FR.columns.intersection(new_column_names)]

# There are rows with --------, drop those rows
combined_FR = combined_FR[combined_FR['id'] != '--------']

combined_FR
# Out:
#             id      date fed_district_code charter_type         city  \
# 1      1020180  20170930                 9          500   SAINT PAUL
# 2      1020201  20170930                 7          500     NEW YORK
# 3      1020902  20170930                10          500        OMAHA
# 4      1022764  20170930                12          500     HONOLULU
# 5      1023220  20170930                 2          500       NEWARK
# ...        ...       ...               ...          ...          ...
# 10848  5110605  20170630                10          500       TOPEKA
# 10849  5113857  20170630                12          500  SANTA MARIA
# 10850  5116344  20170630                12          500      OAKLAND
# 10851  5116353  20170630                12          500    YUBA CITY
# 10852  5136922  20170630                 7          500       CARMEL
#
#              country parent_id                   lei  \
# 1      UNITED STATES         0  549300TXP74T8NJZJW60
# 2      UNITED STATES   3232316  549300LBOHZ4QSIWU288
# 3      UNITED STATES         0                     0
# 4      UNITED STATES         0  549300W3YEAOZ4KGG849
# 5      UNITED STATES   3587146                     0
# ...              ...       ...                   ...
# 10848  UNITED STATES         0                     0
# 10849  UNITED STATES         0  549300LRW3N23RUSWN53
# 10850  UNITED STATES         0  549300557SO55H4J8018
# 10851  UNITED STATES         0  5493007TQPQO80U64N30
# 10852  UNITED STATES   3444847                     0
#
#                                    name_legal                         name  \
# 1                BREMER FINANCIAL CORPORATION             BREMER FNCL CORP
# 2                               HSBC USA INC.                     HSBC USA
# 3            FIRST NATIONAL OF NEBRASKA, INC.              FIRST NAT OF NE
# 4             CENTRAL PACIFIC FINANCIAL CORP.           CENTRAL PACIFIC FC
# 5      B.N.Y. HOLDINGS (DELAWARE) CORPORATION             BNY HOLD DE CORP
# ...                                       ...                          ...
# 10848                    TOPEKA BANCORP, INC.                    TOPEKA BC
# 10849        COMMUNITY BANCORP OF SANTA MARIA  COMMUNITY BC OF SANTA MARIA
# 10850                      CALIFORNIA BANCORP                CALIFORNIA BC
# 10851          RIVER VALLEY COMMUNITY BANCORP        RIVER VALLEY CMNTY BC
# 10852                AMERICAN CAPITAL BANCORP              AMERICAN CAP BC
#
#       org_type fed_regulator state
# 1            1           FRS    MN
# 2            1           FRS    NY
# 3            1           FRS    NE
# 4            1           FRS    HI
# 5            1           FRS    DE
# ...        ...           ...   ...
# 10848        1           FRS    KS
# 10849        1           FRS    CA
# 10850        1           FRS    CA
# 10851        1           FRS    CA
# 10852        1           FRS    IN
#
# [10849 rows x 13 columns]

# %%
combined_FR[combined_FR['parent_id'] == "0"]
# Out:
#             id      date fed_district_code charter_type         city  \
# 1      1020180  20170930                 9          500   SAINT PAUL
# 3      1020902  20170930                10          500        OMAHA
# 4      1022764  20170930                12          500     HONOLULU
# 6      1025309  20170930                12          500     HONOLULU
# 7      1025541  20170930                12          500   SAN RAFAEL
# ...        ...       ...               ...          ...          ...
# 10847  5109672  20170630                 6          500     ANNISTON
# 10848  5110605  20170630                10          500       TOPEKA
# 10849  5113857  20170630                12          500  SANTA MARIA
# 10850  5116344  20170630                12          500      OAKLAND
# 10851  5116353  20170630                12          500    YUBA CITY
#
#              country parent_id                   lei  \
# 1      UNITED STATES         0  549300TXP74T8NJZJW60
# 3      UNITED STATES         0                     0
# 4      UNITED STATES         0  549300W3YEAOZ4KGG849
# 6      UNITED STATES         0  5493006Q8BQ8AD8M2U33
# 7      UNITED STATES         0                     0
# ...              ...       ...                   ...
# 10847  UNITED STATES         0                     0
# 10848  UNITED STATES         0                     0
# 10849  UNITED STATES         0  549300LRW3N23RUSWN53
# 10850  UNITED STATES         0  549300557SO55H4J8018
# 10851  UNITED STATES         0  5493007TQPQO80U64N30
#
#                              name_legal                         name org_type  \
# 1          BREMER FINANCIAL CORPORATION             BREMER FNCL CORP        1
# 3      FIRST NATIONAL OF NEBRASKA, INC.              FIRST NAT OF NE        1
# 4       CENTRAL PACIFIC FINANCIAL CORP.           CENTRAL PACIFIC FC        1
# 6            BANK OF HAWAII CORPORATION              BANK OF HI CORP        1
# 7            WESTAMERICA BANCORPORATION               WESTAMERICA BC        1
# ...                                 ...                          ...      ...
# 10847            NOBLE BANCSHARES, INC.                  NOBLE BSHRS        1
# 10848              TOPEKA BANCORP, INC.                    TOPEKA BC        1
# 10849  COMMUNITY BANCORP OF SANTA MARIA  COMMUNITY BC OF SANTA MARIA        1
# 10850                CALIFORNIA BANCORP                CALIFORNIA BC        1
# 10851    RIVER VALLEY COMMUNITY BANCORP        RIVER VALLEY CMNTY BC        1
#
#       fed_regulator state
# 1               FRS    MN
# 3               FRS    NE
# 4               FRS    HI
# 6               FRS    HI
# 7               FRS    CA
# ...             ...   ...
# 10847           FRS    AL
# 10848           FRS    KS
# 10849           FRS    CA
# 10850           FRS    CA
# 10851           FRS    CA
#
# [10085 rows x 13 columns]

# %% [markdown]
# # 10085 parent ids are zeroes.
# # assign the parent id number the same value of the id column, i.e.

# %%
# Step 1: Replace 'parent_id' values of 0 with 'id' values from the same rows
combined_FR.loc[combined_FR['parent_id'] == "0", 'parent_id'] = combined_FR.loc[combined_FR['parent_id'] == "0", 'id']

# Drop all rows that contain any missing values
#combined_FR.dropna(inplace=True)

combined_FR[combined_FR['parent_id'] == "0"]
# Out:
# Empty DataFrame
# Columns: [id, date, fed_district_code, charter_type, city, country, parent_id, lei, name_legal, name, org_type, fed_regulator, state]
# Index: []

# %% [markdown]
# # Merging the Databset

# %% [markdown]
# merger on parent_id of call and id of FR
# 1. Renaming Columns: appends "_call" to the names of all columns in the call df, except for the "date" column, which is left unchanged for merging purposes.
#
# 2. Creating Common Identifiers: It creates a new column common_id_L1 in both call df and FR df. In call df, common_id_call is set to parent_id_call; in FR df, common_id_call is set to id. This common identifier is used for merging the two datasets.
#
# 3. Merging Datasets: The datasets are merged on the common_id_call and date.

# %%
# Step 1
new_columns = []
for col in call.columns:
    if col != 'date':
        new_columns.append(col + '_call')
    else:
        new_columns.append(col)
call.columns = new_columns

# %%
# Step 2
call['common_id'] = call['parent_id_call']
combined_FR['common_id'] = combined_FR['id']

# Step 3: Merge the two datasets on 'common_id_L1' and 'date'
# call_FR_combined = pd.merge(call, combined_FR, on=['common_id', 'date'])

# %%
call
# Out:
#              date    id_call  charter_type_call  \
# 0      20170930.0       37.0              200.0
# 1      20170930.0      242.0              200.0
# 2      20170930.0      279.0              300.0
# 3      20170930.0      354.0              200.0
# 4      20170930.0      457.0              200.0
# ...           ...        ...                ...
# 24204  20170331.0  5050028.0              200.0
# 24205  20170331.0  5083316.0                0.0
# 24206  20170331.0  5086072.0              200.0
# 24207  20170331.0  5087752.0                0.0
# 24208  20170331.0  5113866.0                0.0
#
#                         name_legal_call                     name_call  \
# 0                BANK OF HANCOCK COUNTY           BANK OF HANCOCK CTY
# 1      FIRST COMMUNITY BANK XENIA-FLORA    FIRST CMNTY BK XENIA FLORA
# 2           MINEOLA COMMUNITY BANK, SSB          MINEOLA CMNTY BK SSB
# 3                      BISON STATE BANK                   BISON ST BK
# 4                      LOWRY STATE BANK                   LOWRY ST BK
# ...                                 ...                           ...
# 24204    INTERNATIONAL BANK OF COMMERCE      INTERNATIONAL BK OF CMRC
# 24205         DESJARDINS FLORIDA BRANCH  FEDERATION DES CAISSES FL BR
# 24206                    BLUE GATE BANK                  BLUE GATE BK
# 24207                     HUDSON BRANCH  ROYAL BK OF CANADA HUDSON BR
# 24208                   NEW YORK BRANCH           TAIWAN BUS BK NY BR
#
#        org_type_call  fed_district_code_call      city_call   country_call  \
# 0                1.0                     6.0         SPARTA  UNITED STATES
# 1                1.0                     8.0          XENIA  UNITED STATES
# 2                6.0                    11.0        MINEOLA  UNITED STATES
# 3                1.0                    10.0          BISON  UNITED STATES
# 4                1.0                     9.0          LOWRY  UNITED STATES
# ...              ...                     ...            ...            ...
# 24204            1.0                    10.0  OKLAHOMA CITY  UNITED STATES
# 24205            0.0                     0.0     HALLANDALE  UNITED STATES
# 24206            1.0                    12.0     COSTA MESA  UNITED STATES
# 24207            0.0                     0.0    JERSEY CITY  UNITED STATES
# 24208            0.0                     0.0       NEW YORK  UNITED STATES
#
#       state_call fed_regulator2_call lei_call  parent_id_call  common_id
# 0             GA                FDIC        0            37.0       37.0
# 1             IL                 FRS        0       3088643.0  3088643.0
# 2             TX                FDIC        0       3619720.0  3619720.0
# 3             KS                FDIC        0           354.0      354.0
# 4             MN                FDIC        0       1127016.0  1127016.0
# ...          ...                 ...      ...             ...        ...
# 24204         OK                FDIC        0       1104231.0  1104231.0
# 24205         FL                 OCC        0       5083316.0  5083316.0
# 24206         CA                FDIC        0       5086072.0  5086072.0
# 24207         NJ                 OCC        0       5087752.0  5087752.0
# 24208         NY                 FRS        0       5113866.0  5113866.0
#
# [24207 rows x 14 columns]

# %%
print(call['common_id'].dtype, combined_FR['common_id'].dtype)
print(call['date'].dtype, combined_FR['date'].dtype)
# Out:
# float64 object
# float64 object

# %%
# Convert 'common_id_L1' and 'date' to string in both DataFrames
call['common_id'] = call['common_id'].astype(float)
combined_FR['common_id'] = combined_FR['common_id'].astype(float)

call['date'] = call['date'].astype(float)
combined_FR['date'] = combined_FR['date'].astype(float)

# Now try merging again
call_FR_combined = pd.merge(call, combined_FR, on=['common_id', 'date'])

# %%
call_FR_combined
# Out:
#              date    id_call  charter_type_call  \
# 0      20170930.0     2376.0              300.0
# 1      20170930.0     3971.0              300.0
# 2      20170930.0     5210.0              200.0
# 3      20170930.0     7009.0              200.0
# 4      20170930.0   976703.0              200.0
# ...           ...        ...                ...
# 10971  20170331.0  4041421.0              200.0
# 10972  20170331.0  4155841.0              300.0
# 10973  20170331.0  4160667.0              200.0
# 10974  20170331.0  4210227.0              200.0
# 10975  20170331.0  4262534.0              200.0
#
#                                     name_legal_call            name_call  \
# 0                                      ORITANI BANK           ORITANI BK
# 1                                   MIDCOUNTRY BANK        MIDCOUNTRY BK
# 2                                         ACNB BANK              ACNB BK
# 3                            BESSEMER TRUST COMPANY          BESSEMER TC
# 4                      BESSEMER TRUST COMPANY, N.A.       BESSEMER TC NA
# ...                                             ...                  ...
# 10971  FLORIDA COMMUNITY BANK, NATIONAL ASSOCIATION  FLORIDA CMNTY BK NA
# 10972                                 BAY BANK, FSB           BAY BK FSB
# 10973                      CAPITAL BANK CORPORATION      CAPITAL BK CORP
# 10974                                      NBH BANK               NBH BK
# 10975                            CADENCE BANK, N.A.        CADENCE BK NA
#
#        org_type_call  fed_district_code_call               city_call  \
# 0                1.0                     2.0  TOWNSHIP OF WASHINGTON
# 1                1.0                     9.0             BLOOMINGTON
# 2                1.0                     3.0              GETTYSBURG
# 3                1.0                     2.0              WOODBRIDGE
# 4                1.0                     2.0                NEW YORK
# ...              ...                     ...                     ...
# 10971            1.0                     6.0                  WESTON
# 10972            1.0                     5.0                COLUMBIA
# 10973            1.0                     5.0                 RALEIGH
# 10974            1.0                    10.0       GREENWOOD VILLAGE
# 10975            1.0                     6.0              BIRMINGHAM
#
#         country_call state_call  ... charter_type                    city  \
# 0      UNITED STATES         NJ  ...          500  TOWNSHIP OF WASHINGTON
# 1      UNITED STATES         MN  ...          500                   MACON
# 2      UNITED STATES         PA  ...          500              GETTYSBURG
# 3      UNITED STATES         NJ  ...          500              WOODBRIDGE
# 4      UNITED STATES         NY  ...          500              WOODBRIDGE
# ...              ...        ...  ...          ...                     ...
# 10971  UNITED STATES         FL  ...          500                  WESTON
# 10972  UNITED STATES         MD  ...          500                COLUMBIA
# 10973  UNITED STATES         NC  ...          500               CHARLOTTE
# 10974  UNITED STATES         CO  ...          500       GREENWOOD VILLAGE
# 10975  UNITED STATES         AL  ...          500                 HOUSTON
#
#              country  parent_id                   lei  \
# 0      UNITED STATES    2692892                     0
# 1      UNITED STATES    3839902                     0
# 2      UNITED STATES    1117464                     0
# 3      UNITED STATES    1246159                     0
# 4      UNITED STATES    1246159                     0
# ...              ...        ...                   ...
# 10971  UNITED STATES    3944628                     0
# 10972  UNITED STATES    1469800                     0
# 10973  UNITED STATES    4160939                     0
# 10974  UNITED STATES    3973888                     0
# 10975  UNITED STATES    4037349  5493005W0IKYDE6MWK10
#
#                                name_legal                    name org_type  \
# 0                  ORITANI FINANCIAL CORP       ORITANI FNCL CORP        1
# 1               MIDCOUNTRY FINANCIAL CORP    MIDCOUNTRY FNCL CORP        1
# 2                        ACNB CORPORATION               ACNB CORP        1
# 3       BESSEMER GROUP, INCORPORATED, THE            BESSEMER GRP        1
# 4       BESSEMER GROUP, INCORPORATED, THE            BESSEMER GRP        1
# ...                                   ...                     ...      ...
# 10971        FCB FINANCIAL HOLDINGS, INC.          FCB FNCL HOLDS        1
# 10972                   BAY BANCORP, INC.                  BAY BC        1
# 10973        CAPITAL BANK FINANCIAL CORP.    CAPITAL BK FNCL CORP        1
# 10974  NATIONAL BANK HOLDINGS CORPORATION  NATIONAL BK HOLDS CORP        1
# 10975                 CADENCE BANCORP LLC          CADENCE BC LLC       11
#
#       fed_regulator state
# 0               FRS    NJ
# 1               FRS    GA
# 2               FRS    PA
# 3               FRS    NJ
# 4               FRS    NJ
# ...             ...   ...
# 10971           FRS    FL
# 10972           FRS    MD
# 10973           FRS    NC
# 10974           FRS    CO
# 10975           FRS    TX
#
# [10976 rows x 26 columns]

# %%
 

# Compute the number of unique subsidiaries for each group
num_sub = call_FR_combined.groupby(['common_id', 'date']).agg(number_subs_1=('id_call', 'nunique')).reset_index()

# Print the results
print(num_sub)
# Out:
#       common_id        date  number_subs_1
# 0     1020180.0  20170331.0              2
# 1     1020180.0  20170630.0              2
# 2     1020180.0  20170930.0              2
# 3     1020180.0  20171231.0              2
# 4     1020395.0  20170630.0              1
# ...         ...         ...            ...
# 9747  5147115.0  20171231.0              1
# 9748  5158269.0  20171231.0              1
# 9749  5163003.0  20171231.0              1
# 9750  5163898.0  20171231.0              1
# 9751  5170805.0  20171231.0              1
#
# [9752 rows x 3 columns]

# %%
num_sub.describe()
# Out:
#           common_id          date  number_subs_1
# count  9.752000e+03  9.752000e+03    9752.000000
# mean   2.211539e+06  2.017089e+07       1.125513
# std    1.178180e+06  3.170263e+02       0.673446
# min    1.020180e+06  2.017033e+07       1.000000
# 25%    1.129487e+06  2.017063e+07       1.000000
# 50%    1.947102e+06  2.017063e+07       1.000000
# 75%    3.160054e+06  2.017123e+07       1.000000
# max    5.170805e+06  2.017123e+07      17.000000

# %% [markdown]
# # from https://rpubs.com/simaan84/bhc
# We observe that, mainly, there is a one-to-one relationship, with the exception for a number of cases. For instance, we note that in the last quarter of 2017, the Wintrust Financial Corporation had 17 subsidiaries:

# %%
# Step 1: Find IDs with 17 subsidiaries
id17 = num_sub.loc[num_sub['number_subs_1'] == 17, 'common_id'].unique()

# Step 2: Get the list of names for these IDs at the specific date
WT_list = call_FR_combined[(call_FR_combined['common_id'].isin(id17)) & (call_FR_combined['date'] == 20171231)]['name_call']

# Step 3: Print sorted list of names
print("\n".join(sorted(WT_list.astype(str))))
# Out:
# BARRINGTON B&TC NA
# BEVERLY B&TC NA
# CHICAGO TC NA
# CRYSTAL LAKE B&TC NA
# FIFC EDGE INTL CORP
# HINSDALE B&TC
# LAKE FOREST B&TC NA
# LIBERTYVILLE B&TC
# NORTHBROOK B&TC
# OLD PLANK TRAIL CMNTY BK NA
# SCHAUMBURG B&TC NA
# ST CHARLES B&TC
# STATE BK OF THE LAKES
# TOWN BK
# VILLAGE B&TC
# WHEATON B&TC
# WINTRUST BK

# %% [markdown]
# On the other hand, if we look at JP Morgan, for instance, we observe that it has two main subsidiaries at the end of 2017. This is in line with the 10-K report from the SEC (see link). Nevertheless, it is also appears that each subsidiary has a number of other subsidiaries in the annual report, which our data does not seem to convey such complexity in the structure:

# %%
# Filtering the DataFrame for JP Morgan entries at the end of 2017
JP_list = call_FR_combined[(call_FR_combined['common_id'] == 1039502) & (call_FR_combined['date'] == 20171231)]['name_legal_call']

# Sorting the names and printing each on a new line
sorted_JP_list = sorted(JP_list.astype(str)) 
print("\n".join(sorted_JP_list))
# Out:
# J.P. MORGAN INTERNATIONAL FINANCE LIMITED
# JPMORGAN CHASE BANK, NATIONAL ASSOCIATION

# %% [markdown]
# # Final Data

# %%
ds_final = call_FR_combined[['date', 'name_legal_call', 'lei_call', 'id_call', 'name_legal', 'lei', 'id']].copy()

# Compute the number of subsidiaries for each BHC in the sample
# Using transform to add the count of subsidiaries directly into the dataframe
ds_final['no_sub'] = ds_final.groupby(['id', 'date'])['id'].transform('count')

# Clean up rows where ID might be NaN (although not explicitly done in the previous example, suggested for robustness)
ds_final = ds_final[ds_final['id'].notna()]


ds_final
# Out:
#              date                               name_legal_call  \
# 0      20170930.0                                  ORITANI BANK
# 1      20170930.0                               MIDCOUNTRY BANK
# 2      20170930.0                                     ACNB BANK
# 3      20170930.0                        BESSEMER TRUST COMPANY
# 4      20170930.0                  BESSEMER TRUST COMPANY, N.A.
# ...           ...                                           ...
# 10971  20170331.0  FLORIDA COMMUNITY BANK, NATIONAL ASSOCIATION
# 10972  20170331.0                                 BAY BANK, FSB
# 10973  20170331.0                      CAPITAL BANK CORPORATION
# 10974  20170331.0                                      NBH BANK
# 10975  20170331.0                            CADENCE BANK, N.A.
#
#                    lei_call    id_call                          name_legal  \
# 0      549300XRBLWUN6J76L65     2376.0              ORITANI FINANCIAL CORP
# 1                         0     3971.0           MIDCOUNTRY FINANCIAL CORP
# 2                         0     5210.0                    ACNB CORPORATION
# 3      549300NEQHXUX4MZIH22     7009.0   BESSEMER GROUP, INCORPORATED, THE
# 4      549300OTTCSOD5OCZ143   976703.0   BESSEMER GROUP, INCORPORATED, THE
# ...                     ...        ...                                 ...
# 10971  549300SGSDB4HQJSLK07  4041421.0        FCB FINANCIAL HOLDINGS, INC.
# 10972                     0  4155841.0                   BAY BANCORP, INC.
# 10973  5493005LC6991GWTPI71  4160667.0        CAPITAL BANK FINANCIAL CORP.
# 10974  549300T7AIY7RU1YDP31  4210227.0  NATIONAL BANK HOLDINGS CORPORATION
# 10975  3XATK28RYORGPDF31217  4262534.0                 CADENCE BANCORP LLC
#
#                         lei       id  no_sub
# 0                         0  2692892       1
# 1                         0  3839902       1
# 2                         0  1117464       1
# 3                         0  1246159       4
# 4                         0  1246159       4
# ...                     ...      ...     ...
# 10971                     0  3944628       1
# 10972                     0  1469800       1
# 10973                     0  4160939       1
# 10974                     0  3973888       1
# 10975  5493005W0IKYDE6MWK10  4037349       1
#
# [10976 rows x 8 columns]

# %% [markdown]
# # Publically Traded Banks

# %%
# Load the dataset from the Federal Reserve Bank of New York that lists publicly traded banks
url = "https://www.newyorkfed.org/medialibrary/media/research/banking_research/data/crsp_20161231.csv"
crsp = pd.read_csv(url)

# Filter ds_final to include only IDs present in the CRSP dataset to find publicly traded banks
ds_final_public = ds_final[ds_final['id'].isin(crsp['entity'])]

# Count unique publicly traded companies and print the result
unique_public_companies = len(ds_final_public['id'].unique())
print(f"Total publicly traded companies: {unique_public_companies}")
# Out:
# Total publicly traded companies: 0

# %%
# Convert 'id' in ds_final and 'entity' in crsp to integers
ds_final['id'] = pd.to_numeric(ds_final['id'], errors='coerce').astype('Int64')
crsp['entity'] = pd.to_numeric(crsp['entity'], errors='coerce').astype('Int64')

# Filter ds_final to include only IDs present in the crsp dataset
ds_final_public = ds_final[ds_final['id'].isin(crsp['entity'].dropna())]

# Count unique publicly traded companies and print the result
unique_public_companies = len(ds_final_public['id'].unique())
print(f"Total publicly traded companies: {unique_public_companies}")
# Out:
# Total publicly traded companies: 421
